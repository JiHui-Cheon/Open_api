# %%
import json

# 네이버 뉴스에서, '전기차'라는 키워드로 검색한 결과
data = """
{
    "lastBuildDate": "Thu, 06 May 2021 14:37:14 +0900",
    "total": 3732150,
    "start": 1,
    "display": 10,
    "items": [
        {
            "title": "현대차, 북극 얼음 얼리기 UN과 함께한다",
            "originallink": "http://www.smedaily.co.kr/news/articleView.html?idxno=203122",
            "link": "http://www.smedaily.co.kr/news/articleView.html?idxno=203122",
            "description": "그린 에너지 모빌리티는 '사파 템포'라 불리는 네팔의 노후화된 미니 <b>전기</b> 버스에 고효율 배터리를 적용할 수 있도록 경제적인 지원을 해주는 핀테크 플랫폼 솔루션이다. 미니 <b>전기</b> 버스 운전자 대부분이 은행에서... ",
            "pubDate": "Thu, 06 May 2021 14:34:00 +0900"
        },
        {
            "title": "부상돈 전북대 교수, 과기부 장관 표창 수상",
            "originallink": "https://www.news1.kr/articles/?4298148",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=421&aid=0005334692",
            "description": "이와 함께 한국물리학회 편집이사, 한국유전체연구회 총무, 미국<b>전기</b>전자학회 강유전체분야 상임위원회 운영위원 등 다양한 대외활동도 펼치고 있다. 올해 3월부터는 연구처장으로 임명돼 전북대가 연구중심대학으로... ",
            "pubDate": "Thu, 06 May 2021 14:34:00 +0900"
        },
        {
            "title": "&quot;태양광 가로등·북극 얼음 만들기&quot; 현대차, UNDP와 지속가능한 솔루션 공개",
            "originallink": "http://www.edaily.co.kr/news/newspath.asp?newsid=02627286629046296",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=103&oid=018&aid=0004921982",
            "description": "‘사파 템포’라 불리는 네팔의 노후화된 미니 <b>전기</b> 버스에 고효율 배터리를 적용할 수 있도록 경제적인 지원을 해주는 핀테크 플랫폼 솔루션이다. 리얼 아이스는 영국의 시안 셔윈이 공모한 내용이다. 얼음이... ",
            "pubDate": "Thu, 06 May 2021 14:34:00 +0900"
        },
        {
            "title": "카카오 &quot;카카오톡 오류 장애, 넷플릭스법 보상 기준 해당 안 돼&quot;",
            "originallink": "http://www.aitimes.com/news/articleView.html?idxno=138393",
            "link": "http://www.aitimes.com/news/articleView.html?idxno=138393",
            "description": "(사진편집=임채린 기자) 카카오가 5일 밤에 있었던 카카오톡 오류 장애 문제를 두고 <b>전기</b>통신사업법... 카카오 관계자의 설명은 <b>전기</b>통신사업법 시행령 '제37조 11'에 해당하는 내용이다. 이 시행령에 따르면... ",
            "pubDate": "Thu, 06 May 2021 14:34:00 +0900"
        },
        {
            "title": "이화<b>전기</b> 거래정지 종료일은?...투자자들 &quot;언제 풀리나&quot;",
            "originallink": "http://www.ggilbo.com/news/articleView.html?idxno=845680",
            "link": "http://www.ggilbo.com/news/articleView.html?idxno=845680",
            "description": "이화<b>전기</b> 거래정지 종료일은?...투자자들 &quot;언제 풀리나&quot; 이화<b>전기</b> 이화<b>전기</b>가 30일부터 거래정지된 가운데 거래정지 종료일에 대한 투자자들의 관심이 뜨겁다. 이화<b>전기</b>는 전원공급장치와 전력변환장치를 주력으로... ",
            "pubDate": "Thu, 06 May 2021 14:34:00 +0900"
        },
        {
            "title": "코로나 장기화 여파 충북 오피스·상가 공실률 증가",
            "originallink": "https://www.nocutnews.co.kr/news/5548284",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=079&aid=0003501046",
            "description": "소규모 상가 임대료는 ㎡당 만 2300원으로 <b>전기</b> 대비 0.56％ 떨어졌고, 전국 평균인 만 9100원을 크게 밑돌았다. 중대형 상가는 ㎡당 만 7600원으로 전 분기보다 0.31％ 떨어졌고 오피스 임대료도 ㎡당 3900원으로 <b>전기</b>... ",
            "pubDate": "Thu, 06 May 2021 14:32:00 +0900"
        },
        {
            "title": "전남도, 캠핑장 3곳 5월 온가족 안심 관광지로 추천",
            "originallink": "http://www.inews24.com/view/1364700",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=031&aid=0000597150",
            "description": "카라반 18대가 있으며, 내부에는 냉장고, TV, <b>전기</b>레인지, 밥솥, 침대, 식기류, 에어컨, 이불 등 집처럼 물품이 준비돼 있다. 자가캠핑이 가능한 곳도 50개를 운영한다. 해남 땅끝 오토캠핑장 일몰[사진=해남군] 특히... ",
            "pubDate": "Thu, 06 May 2021 14:32:00 +0900"
        },
        {
            "title": "KDI &quot;급등한 유가로 물가 0.8%p 상승할 수도…가계 부담 경감 정책 필요&quot;",
            "originallink": "https://www.asiatoday.co.kr/view.php?key=20210506010002938",
            "link": "https://www.asiatoday.co.kr/view.php?key=20210506010002938",
            "description": "특히 국제유가가 반등함에 따라 석유류, <b>전기</b>료 등의 생활 필수품목의 가격이 오를 가능성이 생길 수 있다고 보았다.만약 코로나19 확산세가 커지는 가운데 국제유가가 더 급등한다면, 유가의 영향을 크게 받는 상품에... ",
            "pubDate": "Thu, 06 May 2021 14:32:00 +0900"
        },
        {
            "title": "카카오, 올해 투자 속도 높인다...1분기 역대 최고 실적 달성",
            "originallink": "http://www.aitimes.com/news/articleView.html?idxno=138390",
            "link": "http://www.aitimes.com/news/articleView.html?idxno=138390",
            "description": "카카오 내비게이션을 통해 차량 정비, 방문 세차, <b>전기</b>차 충전, 내 차 팔기 등 신규 서비스도 추진 중이다. 올해 상반기부터는 퀵서비스 사업을 기업 대상으로 출시할 예정이다. 렌터카와 반려동물 택시 사업 등 신규... ",
            "pubDate": "Thu, 06 May 2021 14:32:00 +0900"
        },
        {
            "title": "광양시·포스코 리튬솔루션, 7600억 투자협약",
            "originallink": "https://daily.hankooki.com/lpage/society/202105/dh20210506142518148510.htm?s_ref=nv",
            "link": "https://daily.hankooki.com/lpage/society/202105/dh20210506142518148510.htm?s_ref=nv",
            "description": "리튬은 탄산리튬과 수산화리튬으로 나뉘는데, <b>전기</b>를 생성, 충전하는 역할을 한다. 그동안 이차전지 업계에서는 탄산리튬을 주원료로 하는 양극재를 주로 생산해왔으나, <b>전기</b>자동차의 주행거리를 늘리기 위한... ",
            "pubDate": "Thu, 06 May 2021 14:32:00 +0900"
        }
    ]
} """

json_data = json.loads(data)
print(json_data['items'][0]['title'])
print(json_data['items'][0]['link'])
print(json_data['items'][0]['description'])
# Out:
# 현대차, 북극 얼음 얼리기 UN과 함께한다
# http://www.smedaily.co.kr/news/articleView.html?idxno=203122
# 그린 에너지 모빌리티는 '사파 템포'라 불리는 네팔의 노후화된 미니 <b>전기</b> 버스에 고효율 배터리를 적용할 수 있도록 경제적인 지원을 해주는 핀테크 플랫폼 솔루션이다. 미니 <b>전기</b> 버스 운전자 대부분이 은행에서...

# %%
import requests
import pprint

client_id = 'tU6PKDbDUEkWam1N6RSd'
client_secret = 'BDK08kFWU0'

naver_open_api = 'https://openapi.naver.com/v1/search/shop.json?query=갤럭시노트20'
header_params = {"x-naver-client-id":client_id, "x-naver-client-secret":client_secret}
res = requests.get(naver_open_api, headers=header_params)

if res.status_code == 200:
    data = res.json()
    for index, item in enumerate(data['items']):
        print(index + 1, item['title'], item['link'], item['lprice'], item['mallName'])
        
else:
    print("Error Code:", res.status_code)
# Out:
# 1 삼성전자 <b>갤럭시노트20</b>울트라 5G 256GB SM-N986N (자급제) https://search.shopping.naver.com/gate.nhn?id=23716221490 1198000 네이버
# 2 삼성전자 <b>갤럭시노트20</b> 5G 256GB SM-N981N (자급제) https://search.shopping.naver.com/gate.nhn?id=23716087490 979450 네이버
# 3 삼성 <b>갤럭시 노트20</b> 노트20울트라 자급제 미개통 미사용 2년A/S보증 https://search.shopping.naver.com/gate.nhn?id=24463457981 994000 쿠팡
# 4 삼성전자 <b>갤럭시노트20</b> / <b>갤럭시 노트20</b> 울트라 5G 256GB https://search.shopping.naver.com/gate.nhn?id=82869458901 647000 컴포즈마켓
# 5 삼성전자 <b>갤럭시노트20</b>울트라 5G 256GB SM-N986S (SKT) https://search.shopping.naver.com/gate.nhn?id=23716088492 659970 네이버
# 6 삼성전자 <b>갤럭시노트20</b> 공기계 중고 노트20 울트라 자급제 https://search.shopping.naver.com/gate.nhn?id=26887040777 657800 옥션
# 7 삼성전자 <b>갤럭시노트20</b>울트라 5G 256GB SM-N986K (KT) https://search.shopping.naver.com/gate.nhn?id=23716007491 652000 네이버
# 8 <b>갤럭시 노트20</b>/노트20울트라 자급제 미개통 미사용 삼성공식A/S보증 https://search.shopping.naver.com/gate.nhn?id=26063771369 954240 11번가
# ...

# %%
import requests
import openpyxl

client_id = 'tU6PKDbDUEkWam1N6RSd'
client_secret = 'BDK08kFWU0'
start, num = 1, 0

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions['B'].width = 50
excel_sheet.column_dimensions['C'].width = 50

excel_sheet.append(['랭킹','제목','링크','최저가','쇼핑몰'])

for index in range(10):
    start_number = start + (index * 100)
    naver_open_api = 'https://openapi.naver.com/v1/search/shop.json?query=갤럭시&display=100&start=' + str(start_number)
    header_params = {"x-naver-client-id":client_id, "x-naver-client-secret":client_secret}
    res = requests.get(naver_open_api, headers = header_params)
    if res.status_code == 200:
        data = res.json()
        for item in data['items']:
            num += 1
            excel_sheet.append([num, item['title'], item['link'], item['lprice'], item['mallName']])
            
    else:
            print ("Error Code:", res.status_code)
            
excel_file.save('IT.xlsx')
excel_file.close()

# %% [markdown]
# ## 정부 공공데이터 Open Api 사용하기

# %%
# from urllib import request, urlopen, urlencode
from urllib import request
from urllib.request import urlopen, Request
from urllib.parse import urlencode, quote_plus

url = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty'
queryParams = '?' + urlencode({ quote_plus('ServiceKey') : 'rgeoHf43V%2FMsl9Oy6mpLg4mJ8%2Fnx2ev5B%2FX8vTWqCQJcqphgBCDVpw7rGoEg5Go%2FsBOVqAP780NE%2B6f6MqICjA%3D%3D', quote_plus('serviceKey') : '-', quote_plus('returnType') : 'xml', quote_plus('numOfRows') : '100', quote_plus('pageNo') : '1', quote_plus('sidoName') : '서울', quote_plus('ver') : '1.0' })

request = Request(url + queryParams)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
print (response_body)
# Out:
# b'<OpenAPI_ServiceResponse>\n\t<cmmMsgHeader>\n\t\t<errMsg>SERVICE ERROR</errMsg>\n\t\t<returnAuthMsg>SERVICE_KEY_IS_NOT_REGISTERED_ERROR</returnAuthMsg>\n\t\t<returnReasonCode>30</returnReasonCode>\n\t</cmmMsgHeader>\n</OpenAPI_ServiceResponse>'

# %%
import requests

service_key = 'rgeoHf43V%2FMsl9Oy6mpLg4mJ8%2Fnx2ev5B%2FX8vTWqCQJcqphgBCDVpw7rGoEg5Go%2FsBOVqAP780NE%2B6f6MqICjA%3D%3D'
params = '&numOfRows=10&pageNo=1&sidoName=부산'
open_api = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?ServiceKey='+service_key + params

res = requests.get(open_api)

print(res.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <response>
#   <header>
#     <resultCode>00</resultCode>
#     <resultMsg>NORMAL_CODE</resultMsg>
#   </header>
#   <body>
#     <items>
#       <item>
#         <so2Grade>1</so2Grade>
#         <coFlag/>
#         <khaiValue>77</khaiValue>
#         <so2Value>0.002</so2Value>
#         <coValue>0.2</coValue>
#         <pm10Flag/>
#         <o3Grade>2</o3Grade>
#         <pm10Value>67</pm10Value>
#         <khaiGrade>2</khaiGrade>
#         <sidoName>부산</sidoName>
#         <no2Flag/>
#         <no2Grade>1</no2Grade>
#         <o3Flag/>
#         <so2Flag/>
#         <dataTime>2021-05-06 16:00</dataTime>
#         <coGrade>1</coGrade>
#         <no2Value>0.018</no2Value>
#         <stationName>광복동</stationName>
#         <pm10Grade>2</pm10Grade>
#         <o3Value>0.043</o3Value>
#       </item>
#       <item>
#         <so2Grade/>
#         <coFlag>점검및교정</coFlag>
#         <khaiValue>-</khaiValue>
#         <so2Value>-</so2Value>
# ...

# %%
import requests
from bs4 import BeautifulSoup

service_key = 'rgeoHf43V%2FMsl9Oy6mpLg4mJ8%2Fnx2ev5B%2FX8vTWqCQJcqphgBCDVpw7rGoEg5Go%2FsBOVqAP780NE%2B6f6MqICjA%3D%3D'
params = '&numOfRows=10&pageNo=1&sidoName=부산'
open_api = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?ServiceKey='+service_key + params

res = requests.get(open_api)
soup = BeautifulSoup(res.content, 'html.parser')

data = soup.find_all('item')
for item in data:
#     print(item)
    stationname = item.find('stationname')
    pm10grade = item.find('pm10grade')
    print (stationname.get_text(), pm10grade.get_text())
# Out:
# 광복동 2
# 초량동 2
# 태종대 2
# 청학동 2
# 전포동 2
# 온천동 2
# 명장동 2
# 대연동 2
# 학장동 2
# 덕천동 2
